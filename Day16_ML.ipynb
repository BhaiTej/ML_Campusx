# %% [markdown]
# ## Working with Web Scrapping

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time

# Set up headless Chrome
options = Options()
options.add_argument('--headless')  # run in background
options.add_argument('--disable-gpu')
options.add_argument('--no-sandbox')
options.add_argument('--window-size=1920,1080')
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")

# Initialize the driver
driver = webdriver.Chrome(options=options)

try:
    url = 'https://www.ambitionbox.com/list-of-companies?page=1'
    driver.get(url)

    # Wait for JavaScript content to load
    time.sleep(5)

    # Get the page source
    html = driver.page_source

    # Parse with BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')

    #print(soup.prettify()) it print all html in text

finally:
    driver.quit()

# %%
soup.find_all('h1')
# Out:
# [<h1 class="companyListing__title">
#  							Companies in India
#  						</h1>]

# %%
soup.find_all('h1')[0]
# Out:
# <h1 class="companyListing__title">
# 							Companies in India
# 						</h1>

# %%
soup.find_all('h1')[0].text
# Out:
# '\n\t\t\t\t\t\t\tCompanies in India\n\t\t\t\t\t\t'

# %%
soup.find_all('h2')
# Out:
# [<h2 class="companyCardWrapper__companyName" title="TCS">
#  										TCS
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Accenture">
#  										Accenture
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Wipro">
#  										Wipro
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Cognizant">
#  										Cognizant
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Capgemini">
#  										Capgemini
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="HDFC Bank">
#  										HDFC Bank
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Infosys">
#  										Infosys
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="ICICI Bank">
#  										ICICI Bank
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="HCLTech">
#  										HCLTech
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Tech Mahindra">
#  										Tech Mahindra
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Genpact">
#  										Genpact
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Teleperformance">
#  										Teleperformance
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Concentrix Corporation">
#  										Concentrix Corporation
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Axis Bank">
#  										Axis Bank
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Amazon">
#  										Amazon
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Jio">
#  										Jio
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="iEnergizer">
#  										iEnergizer
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="Reliance Retail">
#  										Reliance Retail
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="IBM">
#  										IBM
#  									</h2>,
#  <h2 class="companyCardWrapper__companyName" title="LTIMindtree">
#  										LTIMindtree
#  									</h2>,
#  <h2 class="main-title body-medium">
#  			Companies by Industry
#  		</h2>,
#  <h2 class="main-title body-medium">
#  			Companies by Locations
#  		</h2>,
#  <h2 class="main-title body-medium">
#  			Companies by Type
#  		</h2>]

# %%
soup.find_all('h2')[0]
# Out:
# <h2 class="companyCardWrapper__companyName" title="TCS">
# 										TCS
# 									</h2>

# %%
for i in soup.find_all('h2'):
    print(i.text)
# Out:
# 										TCS
#
#
# 										Accenture
#
#
# 										Wipro
#
#
# 										Cognizant
#
#
# 										Capgemini
#
#
# 										HDFC Bank
#
#
# 										Infosys
#
#
# 										ICICI Bank
#
#
# 										HCLTech
#
#
# 										Tech Mahindra
#
#
# 										Genpact
#
#
# 										Teleperformance
#
#
# 										Concentrix Corporation
#
#
# 										Axis Bank
#
#
# 										Amazon
#
#
# 										Jio
#
#
# 										iEnergizer
#
#
# 										Reliance Retail
#
#
# 										IBM
#
#
# 										LTIMindtree
#
#
# 			Companies by Industry
#
#
# 			Companies by Locations
#
#
# 			Companies by Type

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Wipro
# Cognizant
# Capgemini
# HDFC Bank
# Infosys
# ICICI Bank
# HCLTech
# Tech Mahindra
# Genpact
# Teleperformance
# Concentrix Corporation
# Axis Bank
# Amazon
# Jio
# iEnergizer
# Reliance Retail
# IBM
# LTIMindtree
# Companies by Industry
# Companies by Locations
# Companies by Type

# %%
for i in soup.find_all('p'):
    print(i.text.strip())
# Out:
# Faster and better experience!
# AmbitionBox
# About Company
# Discover best places to work
# Compare & find best workplace
# Bring your workplace to life
# Highlight your company's perks
# Read reviews for 7L+ companies
# Rate your former or current company
# Discover salaries for 8L+ companies
# Calculate your take home salary
# Check your market value
# Help other jobseekers
# Check your gratuity amount
# Check how much of your HRA is tax-free
# Check your salary hike
# Read interviews for 1L+ companies
# Interviews questions for 2K+ colleges
# Contribute your interview questions
# AmbitionBox Employee Choice Awards - 4th Edition
# AmbitionBox Employee Choice Awards - 3rd Edition
# 2nd Edition
# 1st Edition
# All Filters
# Sort by
# 							 Popular
# Experience
# Location
# Salary
# Industry
# Rating
# Known For
# Size
# Badges
# Type
# Location
# Industry
# Known For
# No. of employees in India
# Badges
# Type
# 9,08,211
# 							results
# Popular
# AmbitionBox Award Winner'24
# AmbitionBox Award Winner'24
# AmbitionBox Award Winner'24
# AmbitionBox Award Winner'24
# AmbitionBox Award Winner'24
# AmbitionBox Award Winner'24
# AmbitionBox Award Winner'24
# AmbitionBox Award Winner'24
# AmbitionBox Award Winner'24
# AmbitionBox Award Winner'24
# AmbitionBox Award Winner'24
# Side-by-side comparison to make informed career
# 										decisions
# Helping over
# 									1 Crore
# 									job seekers every month in choosing their right fit company
# Reviews
# Salaries
# Interviews
# Users/Month
# About Company
# Made with ❤️ in India. Trademarks belong to their respective owners. All
# 					rights reserved © 2025 Info Edge (India) Ltd.

# %%
print("Company Name & Rating:")
companies = soup.select("div.companyCardWrapper")
for company in companies:
    name_tag = company.select_one("h2.companyCardWrapper__companyName")
    rating_tag = company.select_one("span.companyCardWrapper__rating")

    name = name_tag.get_text(strip=True) if name_tag else "N/A"
    rating = rating_tag.get_text(strip=True) if rating_tag else "N/A"

    print(f"- {name} | Rating: {rating}")
# Out:
# Company Name & Rating:
# - TCS | Rating: N/A
# - Accenture | Rating: N/A
# - Wipro | Rating: N/A
# - Cognizant | Rating: N/A
# - Capgemini | Rating: N/A
# - HDFC Bank | Rating: N/A
# - Infosys | Rating: N/A
# - ICICI Bank | Rating: N/A
# - HCLTech | Rating: N/A
# - Tech Mahindra | Rating: N/A
# - Genpact | Rating: N/A
# - Teleperformance | Rating: N/A
# - Concentrix Corporation | Rating: N/A
# - Axis Bank | Rating: N/A
# - Amazon | Rating: N/A
# - Jio | Rating: N/A
# - iEnergizer | Rating: N/A
# - Reliance Retail | Rating: N/A
# - IBM | Rating: N/A
# - LTIMindtree | Rating: N/A

# %%
<div class="companyCardWrapper__primaryInformation">
<div class="companyCardWrapper__companyDetails">
<div class="companyCardWrapper__companyLogo">
<img src="https://static.ambitionbox.com/alpha/company/photos/logos/accenture.jpg" loading="lazy" alt="Accenture logo" onerror="this.onerror=null;this.src='/static/icons/company-placeholder.svg';" width="50" height="50"></div> 
<div class="companyCardWrapper__metaInformation">
<div class="companyCardWrapper__header">
<div class="companyCardWrapper__companyPrimaryDetails">
<div class="companyCardWrapper__companyPrimaryDetailsTopSection">
<a class="companyCardWrapper__companyName companyCardWrapper__companyName--m8">
<h2 title="Accenture" class="companyCardWrapper__companyName">Accenture
									</h2></a> <!----></div></div> 
<button type="button" arialabel="Follow" title="Follow" class="companyCardWrapper__FollowCTA g-btn g-btn--text g-btn--md" fdprocessedid="f45k4q"><!----> <span class="g-btn__label g-btn__label--md g-btn__label--text g-btn__label--loader">Follow</span> <!----></button> <!----></div> <div class="companyCardWrapper__secondaryInformation"><div class="companyCardWrapper__ratingWrapper"><div class="companyCardWrapper__interLinkingWrapper"><div class="companyCardWrapper__companyRatingWrapper"><div class="companyCardWrapper__companyRating"><div class="rating_star_container"><svg width="20" height="20" viewBox="0 0 20 20" fill="none" xmlns="http://www.w3.org/2000/svg"><rect width="20" height="20" rx="4" fill="#9acd32"></rect> <path d="M6.295 16L7.27 11.5632L4 8.57895L8.32 8.18421L10 4L11.68 8.18421L16 8.57895L12.73 11.5632L13.705 16L10 13.6474L6.295 16Z" fill="white"></path></svg> <div class="rating_text rating_text--md "><div style="height:auto;padding-bottom:1px;">
			3.8<!----></div></div></div></div> <div><span class="companyCardWrapper__companyRatingCount">
											(60.7k)
										</span></div></div> <span class="companyCardWrapper__interLinking">
									IT Services &amp; Consulting | Bangalore / Bengaluru +212 other locations
								</span></div> <div class="companyCardWrapper__awardLeaf"><div class="leaf-list-wrapper noscrollbars-sm" data-v-e42c32ba=""><a class="award-leaf" data-v-e92c512e="" data-v-e42c32ba=""><img width="9" height="24" src="https://static.ambitionbox.com/alpha/community/assets/awards/golden-leaf-left.png" alt="golden leaf award" class="obj-contain" data-v-e92c512e=""> <img width="12" height="14" src="https://static.ambitionbox.com/static/awards/black-theme/gold-ambox-logo.svg" alt="AmbitionBox awards" class="ambox-logo" data-v-e92c512e=""> <p data-v-e92c512e="">
		AmbitionBox Award Winner'24
	</p> <img width="9" height="24" src="https://static.ambitionbox.com/alpha/community/assets/awards/golden-leaf-right.png" alt="golden leaf award" class="obj-contain" data-v-e92c512e=""></a> <!----></div></div> <div class="companyCardWrapper__ratingComparisonWrapper"><div><div class="companyCardWrapper__ratingHeader"><img src="https://static.ambitionbox.com/static/companyListing/ThumbsUp.svg" width="14px" height="14px" alt="thumbsup logo"> <span class="companyCardWrapper__ratingHeader--high">Highly Rated For</span></div> <span class="companyCardWrapper__ratingValues">Job Security</span></div> <div><div class="companyCardWrapper__ratingHeader"><img src="https://static.ambitionbox.com/static/companyListing/ThumbsDown.svg" width="14px" height="14px" alt="thumbsdown logo"> <span class="companyCardWrapper__ratingHeader--critical">Critically Rated For</span></div> <span class="companyCardWrapper__ratingValues">Promotions / Appraisal, Salary &amp; Benefits</span></div></div></div></div> <div><div class="viewSalaryInsights"><div class="salaryInsightsText">To view salary insights</div> <div class="designationSelectionText">
								Select designation
							</div></div> <div><div close-on-outside-click="true" class="modal-mask" style="display:none;" data-v-4d861b62=""><div class="modal-wrapper" data-v-4d861b62=""><!----></div></div></div> <!----></div></div></div></div>
# Out:
#   File <string>:15
#     </span></div></div> <span class="companyCardWrapper__interLinking">
#                                                                        ^
# IndentationError: unindent does not match any outer indentation level

# %%
company=soup.find_all('div',class_='companyCardWrapper')

# %%
len(company)
# Out:
# 20

# %%
name=[]
rating=[]
reviews=[]
salaries=[]
interviews=[]
jobs=[]
benifits=[]
for i in company:
    name.append(i.find('h2').text.strip())
    rating.append(i.find('div',class_='rating_text').text.strip())
    reviews.append(i.find_all('span', class_='companyCardWrapper__ActionCount')[0].text.strip())
    salaries.append(i.find_all('span', class_='companyCardWrapper__ActionCount')[1].text.strip())
    interviews.append(i.find_all('span', class_='companyCardWrapper__ActionCount')[2].text.strip())
    jobs.append(i.find_all('span', class_='companyCardWrapper__ActionCount')[3].text.strip())
    benifits.append(i.find_all('span', class_='companyCardWrapper__ActionCount')[4].text.strip())

d={'name':name,'rating':rating,'reviews':reviews,'salaries':salaries,'interviews':interviews,'jobs':jobs,'benifits':benifits}
df=pd.DataFrame(d)
df
# Out:
#                       name rating reviews salaries interviews  jobs benifits
# 0                      TCS    3.7   94.6k     8.9L      10.8k   240    11.9k
# 1                Accenture    3.8   60.7k     5.9L       8.4k  7.5k     7.4k
# 2                    Wipro    3.7   55.6k     4.5L       5.8k  3.6k     5.3k
# 3                Cognizant    3.7   52.8k     5.7L       5.7k   174     6.1k
# 4                Capgemini    3.7   44.5k     4.4L       4.9k  1.8k     4.2k
# 5                HDFC Bank    3.9   41.8k     1.4L       2.3k   142     3.3k
# 6                  Infosys    3.6   41.5k     4.7L       7.7k  1.6k     5.4k
# 7               ICICI Bank    4.0   40.6k     1.5L       2.5k    22     3.8k
# 8                  HCLTech    3.5   38.2k     3.4L         4k   238     4.3k
# 9            Tech Mahindra    3.5   36.9k     2.7L         4k   477     3.8k
# 10                 Genpact    3.8   34.3k     2.1L       3.2k   441     3.9k
# 11         Teleperformance    3.9   31.2k    91.4k       1.9k   342     2.2k
# 12  Concentrix Corporation    3.8   27.6k     1.2L       1.7k   151     3.4k
# 13               Axis Bank    3.8   26.9k    99.3k       1.5k   217     2.2k
# 14                  Amazon    4.1   26.4k     1.3L       5.2k  2.2k     4.4k
# 15                     Jio    4.0   24.5k      61k         2k    69     2.7k
# 16              iEnergizer    4.7   23.7k    22.6k        683   242      568
# 17         Reliance Retail    3.9   23.4k    66.3k       1.6k   101       2k
# 18                     IBM    4.0   23.3k       2L       2.4k  1.2k     2.8k
# 19             LTIMindtree    3.8   22.1k     1.8L         3k   503     1.3k

# %%
name
# Out:
# ['TCS',
#  'Accenture',
#  'Wipro',
#  'Cognizant',
#  'Capgemini',
#  'HDFC Bank',
#  'Infosys',
#  'ICICI Bank',
#  'HCLTech',
#  'Tech Mahindra',
#  'Genpact',
#  'Teleperformance',
#  'Concentrix Corporation',
#  'Axis Bank',
#  'Amazon',
#  'Jio',
#  'iEnergizer',
#  'Reliance Retail',
#  'IBM',
#  'LTIMindtree']

# %%
rating
# Out:
# ['3.7',
#  '3.8',
#  '3.7',
#  '3.7',
#  '3.7',
#  '3.9',
#  '3.6',
#  '4.0',
#  '3.5',
#  '3.5',
#  '3.8',
#  '3.9',
#  '3.8',
#  '3.8',
#  '4.1',
#  '4.0',
#  '4.7',
#  '3.9',
#  '4.0',
#  '3.8']

# %%
reviews
# Out:
# ['94.6k',
#  '60.7k',
#  '55.6k',
#  '52.8k',
#  '44.5k',
#  '41.8k',
#  '41.5k',
#  '40.6k',
#  '38.2k',
#  '36.9k',
#  '34.3k',
#  '31.2k',
#  '27.6k',
#  '26.9k',
#  '26.4k',
#  '24.5k',
#  '23.7k',
#  '23.4k',
#  '23.3k',
#  '22.1k']

# %%
company[0]
# Out:
# <div class="companyCardWrapper" data-widget="CompanyListCard" itemprop="itemListElement" itemscope="itemscope" itemtype="http://schema.org/ListItem"><meta content="1" itemprop="position"/> <meta content="TCS" itemprop="name"/> <meta content="Tata Consultancy Services" itemprop="alternateName"/> <meta content="https://www.ambitionbox.com/overview/tcs-overview" itemprop="url"/> <meta content="https://static.ambitionbox.com/alpha/company/photos/logos/tcs.jpg" itemprop="image"/> <div class="companyCardWrapper__primaryInformation"><div class="companyCardWrapper__companyDetails"><div class="companyCardWrapper__companyLogo"><img alt="Tata Consultancy Services logo" height="50" loading="lazy" onerror="this.onerror=null;this.src='/static/icons/company-placeholder.svg';" src="https://static.ambitionbox.com/alpha/company/photos/logos/tcs.jpg" width="50"/></div> <div class="companyCardWrapper__metaInformation"><div class="companyCardWrapper__header"><div class="companyCardWrapper__companyPrimaryDetails"><div class="companyCardWrapper__companyPrimaryDetailsTopSection"><a class="companyCardWrapper__companyName"><h2 class="companyCardWrapper__companyName" title="TCS">
# 										TCS
# 									</h2></a> <span class="companyCardWrapper__companyVerified"><img alt="verified logo" height="16px" src="https://static.ambitionbox.com/static/icons/verified_blue_tick.svg" width="16px"/></span></div></div> <button arialabel="Follow" class="companyCardWrapper__FollowCTA g-btn g-btn--text g-btn--md" title="Follow" type="button"><!-- --> <span class="g-btn__label g-btn__label--md g-btn__label--text g-btn__label--loader">Follow</span> <!-- --></button> <!-- --></div> <div class="companyCardWrapper__secondaryInformation"><div class="companyCardWrapper__ratingWrapper"><div class="companyCardWrapper__interLinkingWrapper"><div class="companyCardWrapper__companyRatingWrapper"><div class="companyCardWrapper__companyRating"><div class="rating_star_container"><svg fill="none" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg"><rect fill="#9acd32" height="20" rx="4" width="20"></rect> <path d="M6.295 16L7.27 11.5632L4 8.57895L8.32 8.18421L10 4L11.68 8.18421L16 8.57895L12.73 11.5632L13.705 16L10 13.6474L6.295 16Z" fill="white"></path></svg> <div class="rating_text rating_text--md"><div style="height:auto;padding-bottom:1px;">
# 			3.7<!-- --></div></div></div></div> <div><span class="companyCardWrapper__companyRatingCount">
# 											(94.6k)
# 										</span></div></div> <span class="companyCardWrapper__interLinking">
# 									IT Services &amp; Consulting | Bangalore / Bengaluru +393 other locations
# 								</span></div> <!-- --> <div class="companyCardWrapper__ratingComparisonWrapper"><div><div class="companyCardWrapper__ratingHeader"><img alt="thumbsup logo" height="14px" src="https://static.ambitionbox.com/static/companyListing/ThumbsUp.svg" width="14px"/> <span class="companyCardWrapper__ratingHeader--high">Highly Rated For</span></div> <span class="companyCardWrapper__ratingValues">Job Security, Work Life Balance</span></div> <div><div class="companyCardWrapper__ratingHeader"><img alt="thumbsdown logo" height="14px" src="https://static.ambitionbox.com/static/companyListing/ThumbsDown.svg" width="14px"/> <span class="companyCardWrapper__ratingHeader--critical">Critically Rated For</span></div> <span class="companyCardWrapper__ratingValues">Promotions / Appraisal, Salary &amp; Benefits, Work Satisfaction</span></div></div></div></div> <div><div class="viewSalaryInsights"><div class="salaryInsightsText">To view salary insights</div> <div class="designationSelectionText">
# 								Select designation
# 							</div></div> <div><div class="modal-mask" close-on-outside-click="true" data-v-4d861b62="" style="display:none;"><div class="modal-wrapper" data-v-4d861b62=""><!-- --></div></div></div> <!-- --></div></div></div></div> <div class="companyCardWrapper__tertiaryInformation"><a class="companyCardWrapper__ActionWrapper" href="https://www.ambitionbox.com/reviews/tcs-reviews" target="_blank"><span class="companyCardWrapper__ActionCount">94.6k</span> <span class="companyCardWrapper__ActionTitle">Reviews</span></a><a class="companyCardWrapper__ActionWrapper" href="https://www.ambitionbox.com/salaries/tcs-salaries" target="_blank"><span class="companyCardWrapper__ActionCount">8.9L</span> <span class="companyCardWrapper__ActionTitle">Salaries</span></a><a class="companyCardWrapper__ActionWrapper" href="https://www.ambitionbox.com/interviews/tcs-interview-questions" target="_blank"><span class="companyCardWrapper__ActionCount">10.8k</span> <span class="companyCardWrapper__ActionTitle">Interviews</span></a><a class="companyCardWrapper__ActionWrapper" href="https://www.ambitionbox.com/jobs/tcs-jobs-cmp" target="_blank"><span class="companyCardWrapper__ActionCount">240</span> <span class="companyCardWrapper__ActionTitle">Jobs</span></a><a class="companyCardWrapper__ActionWrapper" href="https://www.ambitionbox.com/benefits/tcs-benefits" target="_blank"><span class="companyCardWrapper__ActionCount">11.9k</span> <span class="companyCardWrapper__ActionTitle">Benefits</span></a><a class="companyCardWrapper__ActionWrapper" href="https://www.ambitionbox.com/photos/tcs-photos" target="_blank"><span class="companyCardWrapper__ActionCount">87</span> <span class="companyCardWrapper__ActionTitle">Photos</span></a></div> <div><div add-slide-animation="true" class="modal-mask" data-v-4d861b62="" style="display: none;"><div class="modal-wrapper" data-v-4d861b62="" style="--slide-duration: 0.4s;"><!-- --></div></div></div></div>

# %%
final=pd.DataFrame()
l=[]
for j in range(1,11):
    options = Options()
    options.add_argument('--headless')  # run in background
    options.add_argument('--disable-gpu')
    options.add_argument('--no-sandbox')
    options.add_argument('--window-size=1920,1080')
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")
    
    # Initialize the driver
    driver = webdriver.Chrome(options=options)
    
    try:
        url = 'https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
        driver.get(url)
    
        # Wait for JavaScript content to load
        time.sleep(5)
    
        # Get the page source
        html = driver.page_source
    
        # Parse with BeautifulSoup
        soup = BeautifulSoup(html, 'html.parser')
    
        #print(soup.prettify()) it print all html in text
        company=soup.find_all('div',class_='companyCardWrapper')
        name=[]
        rating=[]
        reviews=[]
        salaries=[]
        interviews=[]
        jobs=[]
        benifits=[]
        for i in company:
            name.append(i.find('h2').text.strip())
            rating.append(i.find('div',class_='rating_text').text.strip())
            reviews.append(i.find_all('span', class_='companyCardWrapper__ActionCount')[0].text.strip())
            salaries.append(i.find_all('span', class_='companyCardWrapper__ActionCount')[1].text.strip())
            interviews.append(i.find_all('span', class_='companyCardWrapper__ActionCount')[2].text.strip())
            jobs.append(i.find_all('span', class_='companyCardWrapper__ActionCount')[3].text.strip())
            benifits.append(i.find_all('span', class_='companyCardWrapper__ActionCount')[4].text.strip())
        
        d={'name':name,'rating':rating,'reviews':reviews,'salaries':salaries,'interviews':interviews,'jobs':jobs,'benifits':benifits}
        df=pd.DataFrame(d)
        l.append(df)
    finally:
        driver.quit()

# %%
z=pd.concat(l,ignore_index=True)
z.tail(15)
# Out:
#                                 name rating reviews salaries interviews jobs  \
# 185                    Berger Paints    3.7    3.3k     8.8k        273  193
# 186         Carelon Global Solutions    3.9    3.3k      25k        372   11
# 187     Godrej & Boyce Manufacturing    3.9    3.2k    14.8k        185   52
# 188      Samvardhana Motherson Group    3.7    3.2k    12.1k        223   10
# 189                         Lenskart    3.2    3.3k      11k        327  170
# 190                           Subros    3.8    3.3k    11.9k        175    1
# 191              Pidilite Industries    4.3    3.2k      10k        210    5
# 192  Automatic Data Processing (ADP)    4.0    3.3k    19.9k        247   28
# 193          Alembic Pharmaceuticals    4.0    3.2k    13.8k        209   66
# 194                 American Express    4.2    3.3k    21.2k        370  144
# 195                  Bank of America    4.2    3.3k    25.3k        244  102
# 196                           Abbott    4.1    3.2k    10.7k        155  270
# 197                           Sodexo    4.1    3.2k     9.4k        169   91
# 198           Jindal Steel and Power    3.9    3.3k    13.7k        332   35
# 199              Hindalco Industries    4.2    3.3k    10.5k        226   64
#
#     benifits
# 185      294
# 186       66
# 187      434
# 188      425
# 189      223
# 190      440
# 191      378
# 192      490
# 193      408
# 194      470
# 195      450
# 196      395
# 197      391
# 198      350
# 199      362
